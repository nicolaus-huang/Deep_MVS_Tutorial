# %%
# !python train.py
# Out:
# train: weights=yolov3.pt, cfg=, data=data/mydata.yaml, hyp=data/hyps/hyp.scratch.yaml, epochs=300, batch_size=4, imgsz=1280, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, adam=False, sync_bn=False, workers=0, project=runs/train, name=exp, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, patience=100, freeze=0, save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: skipping check (not a git repository), for updates see https://github.com/ultralytics/yolov3
# requirements: PyYAML>=5.3.1 not found and is required by YOLOv3, attempting auto-update...
# requirements: 'pip install PyYAML>=5.3.1' skipped (offline)
# YOLOv3 🚀 2021-12-2 torch 1.10.0+cu102 CUDA:0 (Tesla V100-PCIE-32GB, 32510MiB)
#
# ...

# %%
cd runs
# Out:
# /public/home/huanggroup6/yolov3-master/runs

# %%
cd ..
# Out:
# /public/home/huanggroup6/yolov3-master

# %%
# !pip list
# Out:
# Package                 Version
# ----------------------- ---------
# absl-py                 1.0.0
# alembic                 1.1.0
# asn1crypto              0.24.0
# async-generator         1.10
# attrs                   19.1.0
# backcall                0.1.0
# beautifulsoup4          4.8.0
# bleach                  3.1.0
# blinker                 1.4
# bokeh                   1.3.4
# cachetools              4.2.4
# certifi                 2021.10.8
# certipy                 0.1.3
# cffi                    1.12.3
# chardet                 3.0.4
# charset-normalizer      2.0.8
# Click                   7.0
# cloudpickle             1.2.2
# conda                   4.7.10
# conda-package-handling  1.4.0
# cryptography            2.7
# cycler                  0.11.0
# Cython                  0.29.13
# cytoolz                 0.10.0
# dask                    2.2.0
# decorator               4.4.0
# defusedxml              0.5.0
# dill                    0.3.0
# ...
